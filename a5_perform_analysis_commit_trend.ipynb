# %%
import requests
import pandas as pd
import numpy as np
from datetime import datetime
import time
import json
import numpy
import matplotlib.pyplot as plt
import matplotlib
import re

import warnings 
warnings. filterwarnings('ignore')

import joypy

# %%
# Replace with your GitHub username, repository name, and access token # timzzy deepTralog tensorflow
username = "timzzy"
repository = "deepTralog"
access_token = "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"

json_name =  repository

frameworkx_repository = "deepTralog"
framework1_repository = "tensorflow"
framework2_repository = "jax"
framework3_repository = "onnx"
framework4_repository = "chainer"
framework5_repository = "mxnet"
framework6_repository = "deeplearning4j"
framework7_repository = "aspnetcore"
framework8_repository = "spring-framework"
framework9_repository = "yii2"
framework10_repository = "CodeIgniter4"
framework11_repository = "node"
framework12_repository = "symfony"
framework13_repository = "pytorch"
framework14_repository = "keras"

# %%
def fetch_json(json_name):
    with open("raw_json/"+json_name  + ".json", 'r') as json_file:
        json_data = json.load(json_file)
    return json_data




# Function to extract all the labels for an issue
def issue_labels(json_name):
    fetch_issue = fetch_json(json_name)
    #print (len(fetch_issue))
     
              
    if fetch_issue:
        for issue in fetch_issue:
            label_names = [label['name'] for label in issue['labels']]
            labels_issue = concatenate_arrayVal(label_names)
            return labels_issue
    else:
        print(f"Error: Issue labels can not be generated")
        return []
    
    
    
    
# ********************This function changes all the elements in an array to list
def concatenate_arrayVal(arrayVal):
    if isinstance(arrayVal, list):
        concat_value = ', '.join(arrayVal)
        return concat_value
    else:
        return []
    

#*********Date difference*********************    
def count_day_difference_individual(iso_datetime1, iso_datetime2):
    try:
        # Parse the ISO dates with time into datetime objects
        datetime1 = datetime.fromisoformat(iso_datetime1)
        datetime2 = datetime.fromisoformat(iso_datetime2)

        # Calculate the difference in days
        difference = abs((datetime2 - datetime1).days)

        return difference
    except ValueError:
        #print("Invalid datetime format. Please use the ISO format (YYYY-MM-DDTHH:MM:SS)")
        return None
    
    
    
#*********Date difference*********************    
def count_day_difference_df(start_date, end_date):
    if pd.isnull(start_date) or pd.isnull(end_date):
        return None
    else:
        start_date = datetime.fromisoformat(start_date)
        end_date = datetime.fromisoformat(end_date)
        return abs((end_date - start_date).days)
    
    
def remove_special_characters(text):
    return re.sub(r'[^a-zA-Z0-9\s]', '', text)

def remove_special_characters_except_comma(text):
    # Keep only alphabetic characters, digits, spaces, and commas
    cleaned_text = re.sub(r'[^a-zA-Z0-9, ]', '', text)
    return cleaned_text

#getbthe last element in a URL
def URL_last_element(url):
    parsed_url = urlparse(url)
    path_parts = parsed_url.path.split('/')
    last_element = path_parts[-1] if path_parts[-1] else path_parts[-2]
    return last_element

# %%
try:
    all_commit_json_deepTralog = fetch_json("all_commits_deepTralog")  
    all_commit_json_deepTralog = sorted(all_commit_json_deepTralog, key=lambda x: x['commit']['author']['date'], reverse=False) #reverse the order to show in ascending order because I cannot sort the original data fatched from Github   
except Exception as e:
    print("could not get all commits deepTralog")
    
try:
    all_commit_json_tensorflow = fetch_json("all_commits_tensorflow")  
    all_commit_json_tensorflow = sorted(all_commit_json_tensorflow, key=lambda x: x['commit']['author']['date'], reverse=False) 
except Exception as e:
    print("could not get all commits tensorflow")       

try:
    all_commit_json_jax = fetch_json("all_commits_jax")  
    all_commit_json_jax = sorted(all_commit_json_jax, key=lambda x: x['commit']['author']['date'], reverse=False) 
except Exception as e:
    print("could not get all commits jax")    
    
try:
    all_commit_json_onnx = fetch_json("all_commits_onnx")  
    all_commit_json_onnx = sorted(all_commit_json_onnx, key=lambda x: x['commit']['author']['date'], reverse=False) 
except Exception as e:
    print("could not get all commits onnx")    

try:
    all_commit_json_chainer = fetch_json("all_commits_chainer")  
    all_commit_json_chainer = sorted(all_commit_json_chainer, key=lambda x: x['commit']['author']['date'], reverse=False) 
except Exception as e:
    print("could not get all commits chainer")    

try:
    all_commit_json_mxnet = fetch_json("all_commits_mxnet")  
    all_commit_json_mxnet = sorted(all_commit_json_mxnet, key=lambda x: x['commit']['author']['date'], reverse=False) 
except Exception as e:
    print("could not get all commits Mxnet")    

try:
    all_commit_json_deeplearning4j = fetch_json("all_commits_deeplearning4j")  
    all_commit_json_deeplearning4j = sorted(all_commit_json_deeplearning4j, key=lambda x: x['commit']['author']['date'], reverse=False) 
except Exception as e:
    print("could not get all commits deeplearning4j")    

    
try:
    all_commit_json_aspnetcore = fetch_json("all_commits_aspnetcore")  
    all_commit_json_aspnetcore = sorted(all_commit_json_aspnetcore, key=lambda x: x['commit']['author']['date'], reverse=False) 
except Exception as e:
    print("could not get all commits aspnetcore")    

try:
    all_commit_json_spring = fetch_json("all_commits_spring-framework")  
    all_commit_json_spring = sorted(all_commit_json_spring, key=lambda x: x['commit']['author']['date'], reverse=False) 
except Exception as e:
    print("could not get all commits spring-framework")    

try:
    all_commit_json_tensorflow = fetch_json("all_commits_tensorflow")  
    all_commit_json_tensorflow = sorted(all_commit_json_tensorflow, key=lambda x: x['commit']['author']['date'], reverse=False) 
except Exception as e:
    print("could not get all commits tensorflow")    
    
try:
    all_commit_json_yii2 = fetch_json("all_commits_yii2")  
    all_commit_json_yii2 = sorted(all_commit_json_yii2, key=lambda x: x['commit']['author']['date'], reverse=False) 
except Exception as e:
    print("could not get all commits Yii2")

try:
    all_commit_json_CodeIgniter4 = fetch_json("all_commits_CodeIgniter4")  
    all_commit_json_CodeIgniter4 = sorted(all_commit_json_CodeIgniter4, key=lambda x: x['commit']['author']['date'], reverse=False) 
except Exception as e:
    print("could not get all commits CodeIgniter4")        

try:
    all_commit_json_node = fetch_json("all_commits_node")  
    all_commit_json_node = sorted(all_commit_json_node, key=lambda x: x['commit']['author']['date'], reverse=False) 
except Exception as e:
    print("could not get all commits node")    
    
try:
    all_commit_json_symfony = fetch_json("all_commits_symfony")  
    all_commit_json_symfony = sorted(all_commit_json_symfony, key=lambda x: x['commit']['author']['date'], reverse=False) 
except Exception as e:
    print("could not get all commits symfony")    
    
try:
    all_commit_json_pytorch = fetch_json("all_commits_pytorch")  
    all_commit_json_pytorch = sorted(all_commit_json_pytorch, key=lambda x: x['commit']['author']['date'], reverse=False) 
except Exception as e:
    print("could not get all commits pytorch")    
    
try:
    all_commit_json_keras = fetch_json("all_commits_keras")  
    all_commit_json_keras = sorted(all_commit_json_keras, key=lambda x: x['commit']['author']['date'], reverse=False) 
except Exception as e:
    print("could not get all commits keras")

# %%
if all_commit_json_deepTralog:
    commit_list_deepTralog = []
   
    for commit in all_commit_json_deepTralog:
        commit_dict_deepTralog = {}
        commit_dict_deepTralog['Date_committed'] = commit['commit']['author']['date']        
        commit_list_deepTralog.append(commit_dict_deepTralog)
        
    df_all_commits_deepTralog = pd.DataFrame(commit_list_deepTralog)
    df_all_commits_deepTralog['Date_committed'] = pd.to_datetime(df_all_commits_deepTralog['Date_committed'])
    df_all_commits_deepTralog['Year_Month'] = df_all_commits_deepTralog['Date_committed'].dt.strftime('%Y-%m')
    dff_deepTralog = df_all_commits_deepTralog.groupby(['Year_Month'])
    counts_deepTralog = dff_deepTralog.size()
    df_count_deepTralog = counts_deepTralog.reset_index(name='Count')
    df_count_deepTralog['Source'] = 'DeepTralog'
else:
    print("No Commit pulled from Repository for deepTralog")
  


if all_commit_json_tensorflow:
    commit_list_tensorflow = []
   
    for commit in all_commit_json_tensorflow:
        commit_dict_tensorflow = {}
        commit_dict_tensorflow['Date_committed'] = commit['commit']['author']['date']        
        commit_list_tensorflow.append(commit_dict_tensorflow)
        
    df_all_commits_tensorflow = pd.DataFrame(commit_list_tensorflow)
    df_all_commits_tensorflow['Date_committed'] = pd.to_datetime(df_all_commits_tensorflow['Date_committed'])
    df_all_commits_tensorflow['Year_Month'] = df_all_commits_tensorflow['Date_committed'].dt.strftime('%Y-%m')
    dff_tensorflow = df_all_commits_tensorflow.groupby(['Year_Month'])
    counts_tensorflow = dff_tensorflow.size()
    df_count_tensorflow = counts_tensorflow.reset_index(name='Count')
    df_count_tensorflow['Source'] = 'Tensorflow'
else:
    print("No Commit pulled from Repository for tensorflow")  
    


if all_commit_json_pytorch:
    commit_list_pytorch = []
   
    for commit in all_commit_json_pytorch:
        commit_dict_pytorch = {}
        commit_dict_pytorch['Date_committed'] = commit['commit']['author']['date']        
        commit_list_pytorch.append(commit_dict_pytorch)
        
    df_all_commits_pytorch = pd.DataFrame(commit_list_pytorch)
    df_all_commits_pytorch['Date_committed'] = pd.to_datetime(df_all_commits_pytorch['Date_committed'])
    df_all_commits_pytorch['Year_Month'] = df_all_commits_pytorch['Date_committed'].dt.strftime('%Y-%m')
    dff_pytorch = df_all_commits_pytorch.groupby(['Year_Month'])
    counts_pytorch = dff_pytorch.size()
    df_count_pytorch = counts_pytorch.reset_index(name='Count')
    df_count_pytorch['Source'] = 'Pytorch'
else:
    print("No Commit pulled from Repository for pytorch")


if all_commit_json_keras:
    commit_list_keras = []
   
    for commit in all_commit_json_keras:
        commit_dict_keras = {}
        commit_dict_keras['Date_committed'] = commit['commit']['author']['date']        
        commit_list_keras.append(commit_dict_keras)
        
    df_all_commits_keras = pd.DataFrame(commit_list_keras)
    df_all_commits_keras['Date_committed'] = pd.to_datetime(df_all_commits_keras['Date_committed'])
    df_all_commits_keras['Year_Month'] = df_all_commits_keras['Date_committed'].dt.strftime('%Y-%m')
    dff_keras = df_all_commits_keras.groupby(['Year_Month'])
    counts_keras = dff_keras.size()
    df_count_keras = counts_keras.reset_index(name='Count')
    df_count_keras['Source'] = 'Keras'
else:
    print("No Commit pulled from Repository for keras") 
    

if all_commit_json_jax:
    commit_list_jax = []
   
    for commit in all_commit_json_jax:
        commit_dict_jax = {}
        commit_dict_jax['Date_committed'] = commit['commit']['author']['date']        
        commit_list_jax.append(commit_dict_jax)
        
    df_all_commits_jax = pd.DataFrame(commit_list_jax)
    df_all_commits_jax['Date_committed'] = pd.to_datetime(df_all_commits_jax['Date_committed'])
    df_all_commits_jax['Year_Month'] = df_all_commits_jax['Date_committed'].dt.strftime('%Y-%m')
    dff_jax = df_all_commits_jax.groupby(['Year_Month'])
    counts_jax = dff_jax.size()
    df_count_jax = counts_jax.reset_index(name='Count')
    df_count_jax['Source'] = 'Jax'
else:
    print("No Commit pulled from Repository for jax")  
    
    
if all_commit_json_mxnet:
    commit_list_mxnet = []
   
    for commit in all_commit_json_mxnet:
        commit_dict_mxnet = {}
        commit_dict_mxnet['Date_committed'] = commit['commit']['author']['date']        
        commit_list_mxnet.append(commit_dict_mxnet)
        
    df_all_commits_mxnet = pd.DataFrame(commit_list_mxnet)
    df_all_commits_mxnet['Date_committed'] = pd.to_datetime(df_all_commits_mxnet['Date_committed'])
    df_all_commits_mxnet['Year_Month'] = df_all_commits_mxnet['Date_committed'].dt.strftime('%Y-%m')
    dff_mxnet = df_all_commits_mxnet.groupby(['Year_Month'])
    counts_mxnet = dff_mxnet.size()
    df_count_mxnet = counts_mxnet.reset_index(name='Count')
    df_count_mxnet['Source'] = 'Mxnet'
else:
    print("No Commit pulled from Repository for mxnet") 
    

if all_commit_json_deeplearning4j:
    commit_list_deeplearning4j = []
   
    for commit in all_commit_json_deeplearning4j:
        commit_dict_deeplearning4j = {}
        commit_dict_deeplearning4j['Date_committed'] = commit['commit']['author']['date']        
        commit_list_deeplearning4j.append(commit_dict_deeplearning4j)
        
    df_all_commits_deeplearning4j = pd.DataFrame(commit_list_deeplearning4j)
    df_all_commits_deeplearning4j['Date_committed'] = pd.to_datetime(df_all_commits_deeplearning4j['Date_committed'])
    df_all_commits_deeplearning4j['Year_Month'] = df_all_commits_deeplearning4j['Date_committed'].dt.strftime('%Y-%m')
    dff_deeplearning4j = df_all_commits_deeplearning4j.groupby(['Year_Month'])
    counts_deeplearning4j = dff_deeplearning4j.size()
    df_count_deeplearning4j = counts_deeplearning4j.reset_index(name='Count')
    df_count_deeplearning4j['Source'] = 'Deeplearning4j'
else:
    print("No Commit pulled from Repository for deeplearning4j")
    

if all_commit_json_aspnetcore:
    commit_list_aspnetcore = []
   
    for commit in all_commit_json_aspnetcore:
        commit_dict_aspnetcore = {}
        commit_dict_aspnetcore['Date_committed'] = commit['commit']['author']['date']        
        commit_list_aspnetcore.append(commit_dict_aspnetcore)
        
    df_all_commits_aspnetcore = pd.DataFrame(commit_list_aspnetcore)
    df_all_commits_aspnetcore['Date_committed'] = pd.to_datetime(df_all_commits_aspnetcore['Date_committed'])
    df_all_commits_aspnetcore['Year_Month'] = df_all_commits_aspnetcore['Date_committed'].dt.strftime('%Y-%m')
    dff_aspnetcore = df_all_commits_aspnetcore.groupby(['Year_Month'])
    counts_aspnetcore = dff_aspnetcore.size()
    df_count_aspnetcore = counts_aspnetcore.reset_index(name='Count')
    df_count_aspnetcore['Source'] = 'Aspnetcore'
else:
    print("No Commit pulled from Repository for aspnetcore")  
    
    
if all_commit_json_yii2:
    commit_list_yii2 = []
   
    for commit in all_commit_json_yii2:
        commit_dict_yii2 = {}
        commit_dict_yii2['Date_committed'] = commit['commit']['author']['date']        
        commit_list_yii2.append(commit_dict_yii2)
        
    df_all_commits_yii2 = pd.DataFrame(commit_list_yii2)
    df_all_commits_yii2['Date_committed'] = pd.to_datetime(df_all_commits_yii2['Date_committed'])
    df_all_commits_yii2['Year_Month'] = df_all_commits_yii2['Date_committed'].dt.strftime('%Y-%m')
    dff_yii2 = df_all_commits_yii2.groupby(['Year_Month'])
    counts_yii2 = dff_yii2.size()
    df_count_yii2 = counts_yii2.reset_index(name='Count')
    df_count_yii2['Source'] = 'Yii2'
else:
    print("No Commit pulled from Repository for yii2") 
    
    
if all_commit_json_spring:
    commit_list_spring = []
   
    for commit in all_commit_json_spring:
        commit_dict_spring = {}
        commit_dict_spring['Date_committed'] = commit['commit']['author']['date']        
        commit_list_spring.append(commit_dict_spring)
        
    df_all_commits_spring = pd.DataFrame(commit_list_spring)
    df_all_commits_spring['Date_committed'] = pd.to_datetime(df_all_commits_spring['Date_committed'])
    df_all_commits_spring['Year_Month'] = df_all_commits_spring['Date_committed'].dt.strftime('%Y-%m')
    dff_spring = df_all_commits_spring.groupby(['Year_Month'])
    counts_spring = dff_spring.size()
    df_count_spring = counts_spring.reset_index(name='Count')
    df_count_spring['Source'] = 'Spring'
else:
    print("No Commit pulled from Repository for spring")  
    

if all_commit_json_CodeIgniter4:
    commit_list_CodeIgniter4 = []
   
    for commit in all_commit_json_CodeIgniter4:
        commit_dict_CodeIgniter4 = {}
        commit_dict_CodeIgniter4['Date_committed'] = commit['commit']['author']['date']        
        commit_list_CodeIgniter4.append(commit_dict_CodeIgniter4)
        
    df_all_commits_CodeIgniter4 = pd.DataFrame(commit_list_CodeIgniter4)
    df_all_commits_CodeIgniter4['Date_committed'] = pd.to_datetime(df_all_commits_CodeIgniter4['Date_committed'])
    df_all_commits_CodeIgniter4['Year_Month'] = df_all_commits_CodeIgniter4['Date_committed'].dt.strftime('%Y-%m')
    dff_CodeIgniter4 = df_all_commits_CodeIgniter4.groupby(['Year_Month'])
    counts_CodeIgniter4 = dff_CodeIgniter4.size()
    df_count_CodeIgniter4 = counts_CodeIgniter4.reset_index(name='Count')
    df_count_CodeIgniter4['Source'] = 'CodeIgniter4'
else:
    print("No Commit pulled from Repository for CodeIgniter4")  
    

if all_commit_json_node:
    commit_list_node = []
   
    for commit in all_commit_json_node:
        commit_dict_node = {}
        commit_dict_node['Date_committed'] = commit['commit']['author']['date']        
        commit_list_node.append(commit_dict_node)
        
    df_all_commits_node = pd.DataFrame(commit_list_node)
    df_all_commits_node['Date_committed'] = pd.to_datetime(df_all_commits_node['Date_committed'])
    df_all_commits_node['Year_Month'] = df_all_commits_node['Date_committed'].dt.strftime('%Y-%m')
    dff_node = df_all_commits_node.groupby(['Year_Month'])
    counts_node = dff_node.size()
    df_count_node = counts_node.reset_index(name='Count')
    df_count_node['Source'] = 'Node'
else:
    print("No Commit pulled from Repository for node")  
    

if all_commit_json_symfony:
    commit_list_symfony = []
   
    for commit in all_commit_json_symfony:
        commit_dict_symfony = {}
        commit_dict_symfony['Date_committed'] = commit['commit']['author']['date']        
        commit_list_symfony.append(commit_dict_symfony)
        
    df_all_commits_symfony = pd.DataFrame(commit_list_symfony)
    df_all_commits_symfony['Date_committed'] = pd.to_datetime(df_all_commits_symfony['Date_committed'])
    df_all_commits_symfony['Year_Month'] = df_all_commits_symfony['Date_committed'].dt.strftime('%Y-%m')
    dff_symfony = df_all_commits_symfony.groupby(['Year_Month'])
    counts_symfony = dff_symfony.size()
    df_count_symfony = counts_symfony.reset_index(name='Count')
    df_count_symfony['Source'] = 'Symfony'
else:
    print("No Commit pulled from Repository for symfony")

# %%
# all_df_commit_combined = pd.concat([df_count_tensorflow, df_count_pytorch, df_count_keras, df_count_jax, df_count_mxnet, df_count_deeplearning4j, df_count_aspnetcore, df_count_yii2, df_count_spring, df_count_CodeIgniter4, df_count_node, df_count_symfony])
all_df_commit_combined = pd.concat([df_count_tensorflow, df_count_pytorch, df_count_keras, df_count_jax, df_count_mxnet, df_count_deeplearning4j])
all_df_commit_combined['Date'] = pd.to_datetime(all_df_commit_combined['Year_Month'], format = '%Y-%m')
all_df_commit_combined['Date_Number'] = all_df_commit_combined['Date'].apply(lambda x:x.toordinal())

all_df_commit_combined2 = pd.concat([df_count_aspnetcore, df_count_yii2, df_count_spring, df_count_CodeIgniter4, df_count_node, df_count_symfony])
all_df_commit_combined2['Date'] = pd.to_datetime(all_df_commit_combined2['Year_Month'], format = '%Y-%m')
all_df_commit_combined2['Date_Number'] = all_df_commit_combined2['Date'].apply(lambda x:x.toordinal())

# %%
numdays = 16
dates = pd.date_range(start = "01-12-2003", end ='31-12-2023',periods=numdays)
xtick_dates = [str(date)[:-12] for date in dates]

fig, ax = joypy.joyplot(all_df_commit_combined,  by = 'Source', column='Date_Number', 
                        colormap=matplotlib.cm.autumn,  xrot=45, overlap=1, fill = True,
#                         labels=['tensorflow', 'pytorch', 'keras', 'jax', 'mxnet', 'deeplearning4j', 'aspnetcore', 'yii2', 'spring', 'CodeIgniter4', 'node', 'symfony'],
                        figsize = (9,5), fade = True, title="Commits Trend for Deep Learning Framework")

ax[-1].set_xticks(range(numdays))
ax[-1].set_xticklabels(xtick_dates)
ax[-1].set_xlim([0, 15])
fig.show()


numdays = 16
dates = pd.date_range(start = "01-12-2003", end ='31-12-2023',periods=numdays)
xtick_dates = [str(date)[:-12] for date in dates]

fig, ax = joypy.joyplot(all_df_commit_combined2,  by = 'Source', column='Date_Number', 
                        colormap=matplotlib.cm.autumn,  xrot=45, overlap=1, fill = True,
                        figsize = (9,5), fade = True, title="Commits Trend for Non-Deep Learning Framework")

ax[-1].set_xticks(range(numdays))
ax[-1].set_xticklabels(xtick_dates)
ax[-1].set_xlim([0, 15])

fig.show()

# %%
numdays = 16
dates = pd.date_range(start = "01-12-2003", end ='31-12-2023',periods=numdays)
xtick_dates = [str(date)[:-12] for date in dates]

fig, ax = joypy.joyplot(all_df_commit_combined2,  by = 'Source', column='Date_Number', 
                        colormap=matplotlib.cm.autumn,  xrot=45, overlap=1, fill = True,
                        figsize = (9,7), fade = True, title="Commits Trend for Non-Deep Learning Framework")

ax[-1].set_xticks(range(numdays))
ax[-1].set_xticklabels(xtick_dates)
ax[-1].set_xlim([0, 15])

fig.show()
